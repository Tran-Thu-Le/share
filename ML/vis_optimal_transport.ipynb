# %% [markdown]
# <a href="https://colab.research.google.com/github/Tran-Thu-Le/share/blob/main/ML/vis_optimal_transport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualization of Optimal Transport with blurring kernel
# =========================================
#
#
# $\newcommand{\dotp}[2]{\langle #1, #2 \rangle}$
# $\newcommand{\enscond}[2]{\lbrace #1, #2 \rbrace}$
# $\newcommand{\pd}[2]{ \frac{ \partial #1}{\partial #2} }$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\umax}[1]{\underset{#1}{\max}\;}$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\uargmin}[1]{\underset{#1}{argmin}\;}$
# $\newcommand{\norm}[1]{\|#1\|}$
# $\newcommand{\abs}[1]{\left|#1\right|}$
# $\newcommand{\choice}[1]{ \left\{  \begin{array}{l} #1 \end{array} \right. }$
# $\newcommand{\pa}[1]{\left(#1\right)}$
# $\newcommand{\diag}[1]{{diag}\left( #1 \right)}$
# $\newcommand{\qandq}{\quad\text{and}\quad}$
# $\newcommand{\qwhereq}{\quad\text{where}\quad}$
# $\newcommand{\qifq}{ \quad \text{if} \quad }$
# $\newcommand{\qarrq}{ \quad \Longrightarrow \quad }$
# $\newcommand{\ZZ}{\mathbb{Z}}$
# $\newcommand{\CC}{\mathbb{C}}$
# $\newcommand{\RR}{\mathbb{R}}$
# $\newcommand{\EE}{\mathbb{E}}$
# $\newcommand{\Zz}{\mathcal{Z}}$
# $\newcommand{\Ww}{\mathcal{W}}$
# $\newcommand{\Vv}{\mathcal{V}}$
# $\newcommand{\Nn}{\mathcal{N}}$
# $\newcommand{\NN}{\mathcal{N}}$
# $\newcommand{\Hh}{\mathcal{H}}$
# $\newcommand{\Bb}{\mathcal{B}}$
# $\newcommand{\Ee}{\mathcal{E}}$
# $\newcommand{\Cc}{\mathcal{C}}$
# $\newcommand{\Gg}{\mathcal{G}}$
# $\newcommand{\Ss}{\mathcal{S}}$
# $\newcommand{\Pp}{\mathcal{P}}$
# $\newcommand{\Ff}{\mathcal{F}}$
# $\newcommand{\Xx}{\mathcal{X}}$
# $\newcommand{\Mm}{\mathcal{M}}$
# $\newcommand{\Ii}{\mathcal{I}}$
# $\newcommand{\Dd}{\mathcal{D}}$
# $\newcommand{\Ll}{\mathcal{L}}$
# $\newcommand{\Tt}{\mathcal{T}}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\al}{\alpha}$
# $\newcommand{\la}{\lambda}$
# $\newcommand{\ga}{\gamma}$
# $\newcommand{\Ga}{\Gamma}$
# $\newcommand{\La}{\Lambda}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\Si}{\Sigma}$
# $\newcommand{\be}{\beta}$
# $\newcommand{\de}{\delta}$
# $\newcommand{\De}{\Delta}$
# $\newcommand{\phi}{\varphi}$
# $\newcommand{\th}{\theta}$
# $\newcommand{\om}{\omega}$
# $\newcommand{\Om}{\Omega}$

# %% [markdown]
# **REMARK: This notebook is a modification of [Optimal Transport with Linear Programming][1] by
# [Gabriel Peyré][2]**
#
# [1]:https://github.com/gpeyre/numerical-tours/blob/master/python/optimaltransp_1_linprog.ipynb
# [2]: https://github.com/gpeyre

# %% [markdown]
# *Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.

# %% [markdown]
# This numerical tours details how to solve the discrete optimal transport
# problem (in the case of measures that are sums of Diracs) using linear
# programming.

# %% [markdown]
# You need to install [CVXPY](https://www.cvxpy.org/). _Warning:_ seems to not be working on Python 3.7, use rather 3.6.

# %%
# !pip install cvxpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.7/dist-packages (1.0.31)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from cvxpy) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from cvxpy) (1.4.1)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy) (2.0.10)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy) (0.6.2.post0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from cvxpy) (0.70.13)
# Requirement already satisfied: scs>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from cvxpy) (3.2.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy) (0.1.5.post2)
# Requirement already satisfied: dill>=0.3.5.1 in /usr/local/lib/python3.7/dist-packages (from multiprocess->cvxpy) (0.3.5.1)

# %% [markdown]
# Import basic packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

# %% [markdown]
# Optimal Transport of Discrete Distributions
# ------------------------------------------
#
# We consider two dicretes distributions
# $$ \al = \sum_{i=1}^n a_i \de_{x_i} \qandq
#    \be = \sum_{j=1}^m b_j \de_{y_j}. $$
#
# where $n,m$ are the number of points, $\de_x$ is the Dirac at
# location $x \in \RR^d$, and $(x_i)_i, (y_j)_j$ are the positions of the diracs in $\RR^d$.

# %% [markdown]
# Dimensions $(n,m)$ of the coulds.

# %%
n = 60
m = 80

# %% [markdown]
# Generate the point clouds $X=(x_i)_i$ and $Y=(y_j)_j$.

# %%
gauss = lambda q,a,c: a*np.random.randn(2, q) + np.transpose(np.tile(c, (q,1)))
X = np.random.randn(2,n)*.3
Y = np.hstack((gauss(int(m/2),.3,[0,1.6]),np.hstack((gauss(int(m/4),.2,[-1,-1]),gauss(int(m/4),.2,[1,-1])))))

# %% [markdown]
# Generate the weights $a,b$.

# %%
normalize = lambda a: a/np.sum(a)
a = normalize(np.random.rand(n, 1))
b = normalize(np.random.rand(m, 1))

# %% [markdown]
# Helper function for display of clouds.

# %%
myplot = lambda x,y,ms,col: plt.scatter(x,y, s=ms*20, edgecolors="k", c=col, linewidths=2)

# %% [markdown]
# Display the point clouds.
# The size of each dot is proportional to its probability density weight.

# %%
plt.figure(figsize = (10,7))
plt.axis("off")
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Compute the cost matrix $C_{i,j} := \norm{x_i-x_j}^2$.

# %%
def distmat(x,y):
    return np.sum(x**2,0)[:,None] + np.sum(y**2,0)[None,:] - 2*x.transpose().dot(y)
C = distmat(X,Y)

# %% [markdown]
# Define the optimiztion variable $P$.

# %%
P = cp.Variable((n,m))

# %% [markdown]
# Define the set of discrete couplings between $\al$ and $\be$
# $$ U(a,b) := \enscond{ P \in \RR_+^{n \times m} }{
#      \forall i, \sum_j P_{i,j} = a_i, \:
#      \forall j, \sum_i P_{i,j} = b_j }. $$

# %%
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]

# %%
print(type(U))
print(type(U[0]))
# Out:
# <class 'list'>
# <class 'cvxpy.constraints.nonpos.Inequality'>

# %% [markdown]
# The Kantorovitch formulation of the optimal transport reads
# $$ P^\star \in \uargmin{P \in U(a,b)} \sum_{i,j} P_{i,j} C_{i,j}.  $$
# Solve it using CVXPY

# %%
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve()

# %% [markdown]
# An optimal coupling $P^\star$ can be shown to be a sparse matrix
# with less than $n+m-1$ non zero entries. An entry $P_{i,j}^\star \neq 0$
# should be understood as a link between $x_{i}$
# and $y_{j}$ where an amount of mass equal to $P_{i,j}^\star$ is transfered.

# %% [markdown]
# Check that the number of non-zero entries in $P^\star$ is $n+m-1$. Beware that we are using an interior point method here, so that entries of $P^\star$ are nevery exactly 0.

# %%
print("Number of non-zero: %d (n + m-1 = %d)" %(len(P.value[P.value>1e-5]), n + m-1))
# Out:
# Number of non-zero: 139 (n + m-1 = 139)

# %% [markdown]
# Display the solution coupling.

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %% [markdown]
# Display the connexion defined by the optimal coupling.

# %%
I,J = np.nonzero(P.value>1e-5)
plt.figure(figsize = (10,7))
plt.axis('off')
for k in range(len(I)):
    h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Displacement Interpolation
# --------------------------
# For any $t \in [0,1]$, one can define a distribution $\mu_t$ such
# that $t \mapsto \mu_t$ defines a geodesic for the Wasserstein metric.
#
#
# Since the $W_2$ distance is a geodesic distance, this geodesic path solves the
# following variational problem
#
# $$ \mu_t = \uargmin{\mu} (1-t)W_2(\al,\mu)^2 + t W_2(\be,\mu)^2. $$
# This can be understood as a generalization of the usual Euclidean
# barycenter to barycenter of distribution. Indeed, in the case that
# $\al = \de_{x}$ and $\be=\de_y$, one has $\mu_t=\de_{x_t}$ where $ x_t =
# (1-t)x+t y $.
#
#
# Once the optimal coupling $P^\star$ has been computed, the
# interpolated distribution is obtained as
#
# $$ \mu_t = \sum_{i,j} P^\star_{i,j} \de_{(1-t)x_{i} + t y_{j}}. $$

# %% [markdown]
# Find the $i,j$ with non-zero $P_{i,j}^\star$.

# %%
I,J = np.nonzero(P.value>1e-5)
Pij = P.value[I,J]

# %% [markdown]
# Display the evolution of $\mu_t$ for a varying value of $t \in [0,1]$.

# %%
plt.figure(figsize =(15,10))
tlist = np.linspace(0, 1, 6)
for i in range(len(tlist)):
    t = tlist[i]
    Xt = (1-t)*X[:,I] + t*Y[:,J]
    plt.subplot(2,3,i+1)
    plt.axis("off")
    for j in range(len(Pij)):
        myplot(Xt[0,j],Xt[1,j],Pij[j]*len(Pij)*6,[[t,0,1-t]])
    plt.title("t = %.1f" %t) 
    plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
    plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# ## Visualization of optimal transport with blurring kernel

# %% [markdown]
# We now visualize the movement of the points via Gaussian kernel blurring. To do this, first create a folder name `figs` and generate and save figures to that folder.

# %%
from numpy.linalg import norm 
import os 
try:
    os.makedirs("figs")
except:
    print("Folder `figs` already existed")


def dic(x, t, w):
    """
        x: coordinates
        t: positions
        w: half_width
    """
    diff = x.T.reshape(-1, 2, 1) - t
    dist = norm(diff, axis=1)
    dic_ = np.power(2, -dist**2/w**2)
    norm_ = norm(dic_, axis=0)
    assert norm_.shape[0] == dic_.shape[1]
    return dic_/norm_

def get_obs_list(X, Y, Pij, I, J, tlist):
    xa = np.min(Y[0,:])-.1
    xb = np.max(Y[0,:])+.1
    ya = np.min(Y[1,:])-.1
    yb = np.max(Y[1,:])+.1 
    x_axis = np.linspace(xa, xb, 51) 
    y_axis = np.linspace(ya, yb, 51) 
    xy_grid = np.meshgrid(x_axis, y_axis) 
    xy = np.stack([xy_grid[0].reshape(-1), xy_grid[1].reshape(-1)], axis = 0) 

    obs_list = []
    Xt_list = []
    for t in tlist:
        Xt = (1-t)*X[:,I] + t*Y[:,J]
        atoms = dic(xy, Xt, 0.15) 
        obs = atoms @ Pij.reshape(-1, 1)
        obs_list += [obs] 
        Xt_list += [Xt]

    infor = {
        "xy_grid": xy_grid,
        "xa": xa,
        "xb": xb,
        "ya": ya,
        "yb": yb,
        "Xt_list": Xt_list,
        "obs_list": obs_list,
    }
    return infor

def save_figs():
    tlist = np.linspace(0, 1, 30)
    infor = get_obs_list(X, Y, Pij, I, J, tlist)
    xa, xb, ya, yb = infor["xa"], infor["xb"], infor["ya"], infor["yb"]
    xy_grid = infor["xy_grid"]
    Xt_list = infor["Xt_list"]
    obs_list = infor["obs_list"] 

    obs_full = np.stack(obs_list)
    obs_max = obs_full.max()
    
    
    for i in range(len(tlist)):
        Xt = Xt_list[i]
        obs = obs_list[i]


        plt.figure(figsize =(5,5))
        plt.xticks([])
        plt.yticks([])
        plt.xlim(xa, xb)
        plt.ylim(ya, yb)
        plt.contourf(xy_grid[0], xy_grid[1], obs.reshape(51, 51),
                    cmap="viridis", levels=100, vmin=0., vmax=obs_max)
        plt.scatter(Xt[0], Xt[1], s=Pij*2500, c="white", edgecolors="black", linewidths=0.5)
        plt.title(f"Time t={round(tlist[i], 2)}") 
        

        plt.savefig(f'figs/time{i}.png', format='png', dpi=300)

        if i in [1, 5, 10, 20, 29]:
            plt.show()

save_figs()
# Out:
# Folder `figs` already existed

# %% [markdown]
# Then save the GIF image in the working directory.

# %%
import imageio
images = []
filenames = [f"figs/time{i}.png" for i in range(30)]
for filename in filenames:
    images.append(imageio.imread(filename))
    imageio.mimsave('opt_tra.gif', images)

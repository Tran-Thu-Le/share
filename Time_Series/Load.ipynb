# %% [markdown]
# <a href="https://colab.research.google.com/github/Tran-Thu-Le/share/blob/main/Time_Series/Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
GITHUB = 'https://raw.githubusercontent.com/Tran-Thu-Le/share/main/Time_Series/coins/'

COIN = {}

KEYS = "BTC ADA AAVE BNB LINK ATOM CRO DOGE EOS ETH IOTA LITE XMR NEM DOT SOL XLM TRON UNI XRP"

KEYS = KEYS.split(" ")

FILES = [
    'coin_Bitcoin.csv', 'coin_Cardano.csv', 'coin_Aave.csv','coin_BinanceCoin.csv', 'coin_ChainLink.csv',
    'coin_Cosmos.csv', 'coin_CryptocomCoin.csv', 'coin_Dogecoin.csv', 'coin_EOS.csv', 'coin_Ethereum.csv',
    'coin_Iota.csv', 'coin_Litecoin.csv', 'coin_Monero.csv', 'coin_NEM.csv', 'coin_Polkadot.csv',
    'coin_Solana.csv', 'coin_Stellar.csv','coin_Tron.csv', 'coin_Uniswap.csv', 'coin_XRP.csv',
]

for k, f in zip(KEYS, FILES):
    df = pd.read_csv(GITHUB+f)
    COIN[k]=df

COIN["BTC"]
# Out:
#        SNo     Name Symbol  ...         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  ...    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  ...    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  ...    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  ...    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  ...     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...  ...           ...           ...           ...
# 2986  2987  Bitcoin    BTC  ...  33897.048590  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin    BTC  ...  34668.548402  2.438396e+10  6.499397e+11
# 2988  2989  Bitcoin    BTC  ...  35287.779766  2.492431e+10  6.615748e+11
# 2989  2990  Bitcoin    BTC  ...  33746.002456  2.672155e+10  6.326962e+11
# 2990  2991  Bitcoin    BTC  ...  34235.193451  2.650126e+10  6.418992e+11
#
# [2991 rows x 10 columns]
